# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
ipl2016 = pd.read_csv("https://raw.githubusercontent.com/shaik4182/ipl-dataset/master/ipl2016.csv")

# %%
ipl2016
# Out:
#     id  season           city        date                        team1  \
# 0    1    2016         Mumbai  04-09-2016               Mumbai Indians
# 1    2    2016        Kolkata  04-10-2016             Delhi Daredevils
# 2    3    2016     Chandigarh  04-11-2016              Kings XI Punjab
# 3    4    2016      Bangalore  04-12-2016  Royal Challengers Bangalore
# 4    5    2016        Kolkata   4/13/2016        Kolkata Knight Riders
# 5    6    2016         Rajkot   4/14/2016      Rising Pune Supergiants
# 6    7    2016          Delhi   4/15/2016              Kings XI Punjab
# 7    8    2016      Hyderabad   4/16/2016          Sunrisers Hyderabad
# 8    9    2016         Mumbai   4/16/2016               Mumbai Indians
# 9   10    2016     Chandigarh   4/17/2016      Rising Pune Supergiants
# 10  11    2016      Bangalore   4/17/2016  Royal Challengers Bangalore
# 11  12    2016      Hyderabad   4/18/2016               Mumbai Indians
# ...

# %%
ipl2016.head(4)
# Out:
#    id  season        city        date                        team1  \
# 0   1    2016      Mumbai  04-09-2016               Mumbai Indians
# 1   2    2016     Kolkata  04-10-2016             Delhi Daredevils
# 2   3    2016  Chandigarh  04-11-2016              Kings XI Punjab
# 3   4    2016   Bangalore  04-12-2016  Royal Challengers Bangalore
#
#                      team2            toss_winner toss_decision  result  \
# 0  Rising Pune Supergiants         Mumbai Indians           bat  normal
# 1    Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 2            Gujarat Lions          Gujarat Lions         field  normal
# 3      Sunrisers Hyderabad    Sunrisers Hyderabad         field  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 0           0      Rising Pune Supergiants            0               9
# 1           0        Kolkata Knight Riders            0               9
# ...

# %%
ipl2016.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
ipl2016.replace(['Mumbai Indians','Kolkata Knight Riders','Royal Challengers Bangalore',
                 'Delhi Daredevils','Gujarat Lions','Kings XI Punjab',
                 'Sunrisers Hyderabad','Rising Pune Supergiants']
                ,['MI','KKR','RCB','DD','GL','KXIP','SRH','RPS'],inplace=True)
ipl2016.head(3)
# Out:
#    id  season        city        date team1 team2 toss_winner toss_decision  \
# 0   1    2016      Mumbai  04-09-2016    MI   RPS          MI           bat
# 1   2    2016     Kolkata  04-10-2016    DD   KKR         KKR         field
# 2   3    2016  Chandigarh  04-11-2016  KXIP    GL          GL         field
#
#    result  dl_applied winner  win_by_runs  win_by_wickets player_of_match  \
# 0  normal           0    RPS            0               9       AM Rahane
# 1  normal           0    KKR            0               9      AD Russell
# 2  normal           0     GL            0               5        AJ Finch
#
#                                                venue          umpire1  \
# 0                                   Wankhede Stadium  HDPK Dharmasena
# 1                                       Eden Gardens           S Ravi
# 2  Punjab Cricket Association IS Bindra Stadium, ...     AK Chaudhary
#
#          umpire2
# 0      CK Nandan
# 1  C Shamshuddin
# 2    VA Kulkarni

# %%
ipl2016['team1'].unique()
# Out:
# array(['MI', 'DD', 'KXIP', 'RCB', 'KKR', 'RPS', 'SRH', 'GL'], dtype=object)

# %%
code = {'team1':{'MI':1, 'DD':2, 'KXIP':3, 'RCB':4, 'KKR':5, 'RPS':7, 'SRH':8, 'GL':9},
       'team2':{'MI':1, 'DD':2, 'KXIP':3, 'RCB':4, 'KKR':5, 'RPS':7, 'SRH':8, 'GL':9}}

# %%
ipl2016.replace(code,inplace=True)

# %%
ipl2016.head(2)
# Out:
#    id  season     city        date  team1  team2 toss_winner toss_decision  \
# 0   1    2016   Mumbai  04-09-2016      1      7          MI           bat
# 1   2    2016  Kolkata  04-10-2016      2      5         KKR         field
#
#    result  dl_applied winner  win_by_runs  win_by_wickets player_of_match  \
# 0  normal           0    RPS            0               9       AM Rahane
# 1  normal           0    KKR            0               9      AD Russell
#
#               venue          umpire1        umpire2
# 0  Wankhede Stadium  HDPK Dharmasena      CK Nandan
# 1      Eden Gardens           S Ravi  C Shamshuddin

# %%
ipl2016.replace({'city':'Mumbai'},'kkr').head(2) # To change spcified value in ro
# Out:
#    id  season     city        date  team1  team2 toss_winner toss_decision  \
# 0   1    2016      kkr  04-09-2016      1      7          MI           bat
# 1   2    2016  Kolkata  04-10-2016      2      5         KKR         field
#
#    result  dl_applied winner  win_by_runs  win_by_wickets player_of_match  \
# 0  normal           0    RPS            0               9       AM Rahane
# 1  normal           0    KKR            0               9      AD Russell
#
#               venue          umpire1        umpire2
# 0  Wankhede Stadium  HDPK Dharmasena      CK Nandan
# 1      Eden Gardens           S Ravi  C Shamshuddin

# %%
ipl2016.replace({'city':'kkr'},'Mumbai').head(2) # To change spcified value in row
# Out:
#    id  season     city        date  team1  team2 toss_winner toss_decision  \
# 0   1    2016   Mumbai  04-09-2016      1      7          MI           bat
# 1   2    2016  Kolkata  04-10-2016      2      5         KKR         field
#
#    result  dl_applied winner  win_by_runs  win_by_wickets player_of_match  \
# 0  normal           0    RPS            0               9       AM Rahane
# 1  normal           0    KKR            0               9      AD Russell
#
#               venue          umpire1        umpire2
# 0  Wankhede Stadium  HDPK Dharmasena      CK Nandan
# 1      Eden Gardens           S Ravi  C Shamshuddin

# %%
ipl2016['player_of_match'].head(4)
# Out:
# 0         AM Rahane
# 1        AD Russell
# 2          AJ Finch
# 3    AB de Villiers
# Name: player_of_match, dtype: object

# %%
#sns.countplot(y='winner', data = matches)
#plt.show
plt.figure(figsize=(10,20))
data = ipl2016.player_of_match.value_counts()
sns.barplot(y = data.index, x = data, orient='h');

# %%
plt.figure(figsize=(16,9))
sns.countplot(x='winner',data=ipl2016)
plt.show()

# %%
ss = data2016['toss_winner'] == data2016['winner']
ss.groupby(ss).size()
# Out:
# False    26
# True     34
# dtype: int64

# %%
#sns.countplot(matches['toss_winner'] == matches['winner'])
sns.countplot(ss);

# %%
toss=ipl2016.groupby(["toss_winner"]).size()
toss
# Out:
# toss_winner
# DD       8
# GL       8
# KKR      6
# KXIP     6
# MI       9
# RCB      6
# RPS      7
# SRH     10
# dtype: int64

# %%
win=ipl2016.groupby(['winner']).size()
win
# Out:
# winner
# DD       7
# GL       9
# KKR      8
# KXIP     4
# MI       7
# RCB      9
# RPS      5
# SRH     11
# dtype: int64

# %%
plt.plot('winner',data=ipl2016)

# %%
ipl2016['toss_winner'].hist(bins=30)

# %%
ipl2016['winner'].hist(bins=30)

# %%
fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('toss_winner')
ax1.set_ylabel('Count of toss winners')
ax1.set_title("toss winners")
toss.plot(kind='bar',color=['r','c','k','r','b','r','m','y'])

ax2 = fig.add_subplot(122)
win.plot(kind = 'bar',color=['r','c','k','r','b','r','m','y'])
ax2.set_xlabel('winner')
ax2.set_ylabel('Count of match winners')
ax2.set_title("Match winners")
# Out:
# Text(0.5, 1.0, 'Match winners')

# %%
plt.style.use('fivethirtyeight')
df_fil=ipl2016[ipl2016['toss_winner']==ipl2016['winner']]
slices=[len(df_fil),(60-len(df_fil))]
plt.pie(slices,labels=['Toss & win','Toss & lose'],startangle=90,shadow=True,explode=(0,0),autopct='%1.1f%%',colors=['r','g'])
fig = plt.gcf()
fig.set_size_inches(6,6)
plt.show()

# %%
sns.pairplot(ipl2016)
